# %% [markdown]
# <a href="https://colab.research.google.com/github/selenophile2005/data-science/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd
import numpy as np

data = np.random.randn(1000)
df = pd.DataFrame(data, columns=['Values'])

sns.histplot(df['Values'], bins=30, kde=True, color='blue')
plt.title("Histogram with KDE")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-71d41cbaab78> in <cell line: 0>()
#       7
#       8 sns.histplot(df['Values'], bins=30, kde=True, color='blue')
# ----> 9 plt.title("Histogram with KDE")
#      10 plt.show()
#
# NameError: name 'plt' is not defined
