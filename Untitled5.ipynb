# %% [markdown]
# <a href="https://colab.research.google.com/github/selenophile2005/data-science/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(0,10,100)
y=np.sin(x)
plt.plot(x,y,label="Sine Wave")
plt.ylabel("sin(x)")
plt.xlabel("x")
plt.legend()
plt.show()

# %%
categories=('A','B','C','D')
values=[19,26,34,9]
plt.bar(categories,values)
# Out:
# <BarContainer object of 4 artists>

# %%
data=np.random.randn(1000)
plt.figure(figsize=(7,5))
plt.hist(data,bins=30,color='green',edgecolor='black',alpha=0.7)
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Histogram Example")
plt.show()

# %%
import seaborn as sns
import pandas as pd
data=np.random.randn(1000)
df=pd.DataFrame(data,columns=['Values'])
sns.histplot(df['Values'],bins=30,kde=True,color='blue')
plt.title("Histogram with KDE")
plt.show()

# %%
tips=sns.load_dataset('tips')
plt.figure(figsize=(6,4))
plt.boxplot(x=tips['total_bill'])
plt.ylabel('Total Bill')
plt.title('Box Plot of Total Bill')
plt.show()

# %%
sns.pairplot(tips,hue='sex')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
